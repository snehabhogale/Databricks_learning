-- %%
SELECT * FROM demo_autoloader.etlcontrol
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>ecname</th><th>metadatatype</th><th>batchsetting</th><th>sourceobject</th><th>sinkobject</th><th>loadsetting</th><th>mappingsettings</th><th>enableflag</th><th>modifieddate</th></tr></thead><tbody><tr><td>2</td><td>orders_demo</td><td>json</td><td>availableNow</td><td>{"schemaname":"demo_autoloader","tablename":"orders_stg"}</td><td>{"schemaname":"demo_autoloader","tablename":"orders"}</td><td>{
--         "mode":"merge"
--     }</td><td>{
--         "mappings":[
--             {
--                 "source":{"path":"$[id]"},
-- ...

-- %%
SELECT * FROM demo_autoloader.query_repo
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>query_name</th><th>query_type</th><th>query_text</th></tr></thead><tbody><tr><td>orders_demo</td><td>merge</td><td>MERGE INTO demo_autoloader.orders AS t
-- USING demo_autoloader.orders_stg AS s
--     ON t.id = s.id
--
-- WHEN MATCHED
--     AND COALESCE(t.sourceid, 0) < s.sourceid
-- THEN UPDATE SET
--     t.id       = s.id,
--     t.customer_id    = s.customer_id,
--     t.product        = s.product,
--     t.quantity       = s.quantity,
--     t.amount         = s.amount,
--     t.status         = s.status,
--     t.sourceid       = s.sourceid,
--     t.loaddtm        = s.loaddtm,
-- ...

-- %%
SELECT * FROM demo_autoloader.autoloader_config
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM demo_autoloader.file_process_logs
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM demo_autoloader.file_process_id_seq
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ecname</th><th>id</th><th>lock_token</th></tr></thead><tbody><tr><td>orders_demo</td><td>7</td><td>70ff6f05-0a12-4d78-b957-bb93eabfc20b</td></tr><tr><td>users_demo</td><td>24</td><td>60740e28-c230-4e38-84df-2b271cfa740d</td></tr></tbody></table></div>

-- %%
SELECT * FROM demo_autoloader.etl_error_log
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>etl_id</th><th>tablename</th><th>filename</th><th>step_name</th><th>status</th><th>cmnts</th><th>pipelinerunid</th><th>createddt</th></tr></thead><tbody><tr><td>2</td><td>orders</td><td></td><td>STEP_13_FOREACH_BATCH</td><td>FAILED</td><td>[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `id` cannot be resolved. Did you mean one of the following? [`amount`, `loaddtm`, `sourceid`, `status`, `date_deleted`]. SQLSTATE: 42703;
-- Filter `==`(_row_num, 1)
-- ...

-- %%
SELECT * FROM demo_autoloader.file_schema_validation_errors
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tablename</th><th>filename</th><th>error_message</th><th>pipelinerunid</th><th>batchid</th><th>created_timestamp</th></tr></thead><tbody></tbody></table></div>

-- %%
SELECT * FROM demo_autoloader.orders
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM demo_autoloader.users
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
